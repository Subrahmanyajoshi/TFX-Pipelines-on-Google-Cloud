# %%
# ! pip3 install kfp==1.8.10
# ! pip3 install tfx==1.5.0
# ! pip3 install pyparsing==2.4.2

# %%
import tensorflow as tf
import tfx
import os

# %%
GCP_REGION = 'us-central1'
ARTIFACT_STORE_URI = 'gs://text-analysis-323506-artifact-store'
ENDPOINT = 'https://1b7bb986cc987470-dot-us-central1.pipelines.googleusercontent.com'
CUSTOM_SERVICE_ACCOUNT = 'my-api-sa@text-analysis-323506.iam.gserviceaccount.com'

PROJECT_ID = !(gcloud config get-value core/project)
PROJECT_ID = PROJECT_ID[0]

# %%
os.environ['GCP_REGION'] = GCP_REGION
os.environ['ARTIFACT_STORE_URI'] = ARTIFACT_STORE_URI
os.environ['CUSTOM_SERVICE_ACCOUNT'] = CUSTOM_SERVICE_ACCOUNT
os.environ['PROJECT_ID'] = PROJECT_ID

# %%
PIPELINE_NAME = 'tfx_covertype_training'
MODEL_NAME = 'tfx_covertype_classifier'
DATA_ROOT_URI = 'gs://text-analysis-323506/covertype'
CUSTOM_TFX_IMAGE = 'gcr.io/{}/{}'.format(PROJECT_ID, PIPELINE_NAME)
RUNTIME_VERSION = '2.6'
PYTHON_VERSION = '3.7'
USE_KFP_SA=False
ENABLE_TUNING=False

# %%
os.environ['PIPELINE_NAME'] = PIPELINE_NAME
os.environ['MODEL_NAME'] = MODEL_NAME
os.environ['DATA_ROOT_URI'] = DATA_ROOT_URI
os.environ['CUSTOM_TFX_IMAGE'] = CUSTOM_TFX_IMAGE
os.environ['RUNTIME_VERSION'] = RUNTIME_VERSION
os.environ['PYTHON_VERSION'] = PYTHON_VERSION
os.environ['USE_KFP_SA'] = str(USE_KFP_SA)
os.environ['ENABLE_TUNING'] = str(ENABLE_TUNING)

# %%
# %cd pipeline
# Out:
# /home/jupyter/TFX-Pipelines-on-Google-Cloud/pipeline

# %%
! tfx pipeline compile --engine kubeflow --pipeline_path runner.py
# Out:
# CLI
# Compiling pipeline
# WARNING:absl:`custom_executor_spec` is deprecated. Please customize component directly.
# WARNING:absl:`transformed_examples` is deprecated. Please use `examples` instead.
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying pipeline.py -> build/lib
# copying runner.py -> build/lib
# copying preprocessing.py -> build/lib
# copying features.py -> build/lib
# copying config.py -> build/lib
# copying model.py -> build/lib
# /opt/conda/lib/python3.7/site-packages/setuptools/command/install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   setuptools.SetuptoolsDeprecationWarning,
# installing to /tmp/tmpczv6m_gz
# running install
# running install_lib
# copying build/lib/preprocessing.py -> /tmp/tmpczv6m_gz
# copying build/lib/features.py -> /tmp/tmpczv6m_gz
# copying build/lib/pipeline.py -> /tmp/tmpczv6m_gz
# copying build/lib/config.py -> /tmp/tmpczv6m_gz
# copying build/lib/model.py -> /tmp/tmpczv6m_gz
# copying build/lib/runner.py -> /tmp/tmpczv6m_gz
# running install_egg_info
# running egg_info
# creating tfx_user_code_Transform.egg-info
# writing tfx_user_code_Transform.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Transform.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Transform.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# reading manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# Copying tfx_user_code_Transform.egg-info to /tmp/tmpczv6m_gz/tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6-py3.7.egg-info
# running install_scripts
# creating /tmp/tmpczv6m_gz/tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/WHEEL
# creating '/tmp/tmpi4t6ij9t/tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6-py3-none-any.whl' and adding '/tmp/tmpczv6m_gz' to it
# adding 'config.py'
# adding 'features.py'
# adding 'model.py'
# adding 'pipeline.py'
# adding 'preprocessing.py'
# adding 'runner.py'
# adding 'tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/METADATA'
# adding 'tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/WHEEL'
# adding 'tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/top_level.txt'
# adding 'tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/RECORD'
# removing /tmp/tmpczv6m_gz
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying pipeline.py -> build/lib
# copying runner.py -> build/lib
# copying preprocessing.py -> build/lib
# copying features.py -> build/lib
# copying config.py -> build/lib
# copying model.py -> build/lib
# /opt/conda/lib/python3.7/site-packages/setuptools/command/install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   setuptools.SetuptoolsDeprecationWarning,
# installing to /tmp/tmpkput336e
# running install
# running install_lib
# copying build/lib/preprocessing.py -> /tmp/tmpkput336e
# copying build/lib/features.py -> /tmp/tmpkput336e
# copying build/lib/pipeline.py -> /tmp/tmpkput336e
# copying build/lib/config.py -> /tmp/tmpkput336e
# copying build/lib/model.py -> /tmp/tmpkput336e
# copying build/lib/runner.py -> /tmp/tmpkput336e
# running install_egg_info
# running egg_info
# creating tfx_user_code_Trainer.egg-info
# writing tfx_user_code_Trainer.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Trainer.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Trainer.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# reading manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# Copying tfx_user_code_Trainer.egg-info to /tmp/tmpkput336e/tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6-py3.7.egg-info
# running install_scripts
# creating /tmp/tmpkput336e/tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/WHEEL
# creating '/tmp/tmp1i8jesf6/tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6-py3-none-any.whl' and adding '/tmp/tmpkput336e' to it
# adding 'config.py'
# adding 'features.py'
# adding 'model.py'
# adding 'pipeline.py'
# adding 'preprocessing.py'
# adding 'runner.py'
# adding 'tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/METADATA'
# adding 'tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/WHEEL'
# adding 'tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/top_level.txt'
# adding 'tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/RECORD'
# removing /tmp/tmpkput336e
# /opt/conda/lib/python3.7/site-packages/kfp/dsl/_container_op.py:1264: FutureWarning: Please create reusable components instead of constructing ContainerOp instances directly. Reusable components are shareable, portable and have compatibility and support guarantees. Please see the documentation: https://www.kubeflow.org/docs/pipelines/sdk/component-development/#writing-your-component-definition-file The components can be created manually (or, in case of python, using kfp.components.create_component_from_func or func_to_container_op) and then loaded using kfp.components.load_component_from_file, load_component_from_uri or load_component_from_text: https://kubeflow-pipelines.readthedocs.io/en/stable/source/kfp.components.html#kfp.components.load_component_from_file
#   category=FutureWarning,
# Pipeline compiled successfully.
# Pipeline package path: /home/jupyter/TFX-Pipelines-on-Google-Cloud/pipeline/tfx_covertype_training.tar.gz

# %%
# !tfx pipeline create --pipeline_path=runner.py --endpoint={ENDPOINT}
# Out:
# CLI
# Creating pipeline
# Detected Kubeflow.
# Use --engine flag if you intend to use a different orchestrator.
# WARNING:absl:`custom_executor_spec` is deprecated. Please customize component directly.
# WARNING:absl:`transformed_examples` is deprecated. Please use `examples` instead.
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying pipeline.py -> build/lib
# copying runner.py -> build/lib
# copying preprocessing.py -> build/lib
# copying features.py -> build/lib
# copying config.py -> build/lib
# copying model.py -> build/lib
# /opt/conda/lib/python3.7/site-packages/setuptools/command/install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   setuptools.SetuptoolsDeprecationWarning,
# installing to /tmp/tmpv3faz_ji
# running install
# running install_lib
# copying build/lib/preprocessing.py -> /tmp/tmpv3faz_ji
# copying build/lib/features.py -> /tmp/tmpv3faz_ji
# copying build/lib/pipeline.py -> /tmp/tmpv3faz_ji
# copying build/lib/config.py -> /tmp/tmpv3faz_ji
# copying build/lib/model.py -> /tmp/tmpv3faz_ji
# copying build/lib/runner.py -> /tmp/tmpv3faz_ji
# running install_egg_info
# running egg_info
# creating tfx_user_code_Transform.egg-info
# writing tfx_user_code_Transform.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Transform.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Transform.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# reading manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# Copying tfx_user_code_Transform.egg-info to /tmp/tmpv3faz_ji/tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6-py3.7.egg-info
# running install_scripts
# creating /tmp/tmpv3faz_ji/tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/WHEEL
# creating '/tmp/tmp4s37nuwi/tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6-py3-none-any.whl' and adding '/tmp/tmpv3faz_ji' to it
# adding 'config.py'
# adding 'features.py'
# adding 'model.py'
# adding 'pipeline.py'
# adding 'preprocessing.py'
# adding 'runner.py'
# adding 'tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/METADATA'
# adding 'tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/WHEEL'
# adding 'tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/top_level.txt'
# adding 'tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/RECORD'
# removing /tmp/tmpv3faz_ji
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying pipeline.py -> build/lib
# copying runner.py -> build/lib
# copying preprocessing.py -> build/lib
# copying features.py -> build/lib
# copying config.py -> build/lib
# copying model.py -> build/lib
# /opt/conda/lib/python3.7/site-packages/setuptools/command/install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   setuptools.SetuptoolsDeprecationWarning,
# installing to /tmp/tmpd7xj44bk
# running install
# running install_lib
# copying build/lib/preprocessing.py -> /tmp/tmpd7xj44bk
# copying build/lib/features.py -> /tmp/tmpd7xj44bk
# copying build/lib/pipeline.py -> /tmp/tmpd7xj44bk
# copying build/lib/config.py -> /tmp/tmpd7xj44bk
# copying build/lib/model.py -> /tmp/tmpd7xj44bk
# copying build/lib/runner.py -> /tmp/tmpd7xj44bk
# running install_egg_info
# running egg_info
# creating tfx_user_code_Trainer.egg-info
# writing tfx_user_code_Trainer.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Trainer.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Trainer.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# reading manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# Copying tfx_user_code_Trainer.egg-info to /tmp/tmpd7xj44bk/tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6-py3.7.egg-info
# running install_scripts
# creating /tmp/tmpd7xj44bk/tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/WHEEL
# creating '/tmp/tmpdlu6cf1a/tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6-py3-none-any.whl' and adding '/tmp/tmpd7xj44bk' to it
# adding 'config.py'
# adding 'features.py'
# adding 'model.py'
# adding 'pipeline.py'
# adding 'preprocessing.py'
# adding 'runner.py'
# adding 'tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/METADATA'
# adding 'tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/WHEEL'
# adding 'tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/top_level.txt'
# adding 'tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/RECORD'
# removing /tmp/tmpd7xj44bk
# /opt/conda/lib/python3.7/site-packages/kfp/dsl/_container_op.py:1264: FutureWarning: Please create reusable components instead of constructing ContainerOp instances directly. Reusable components are shareable, portable and have compatibility and support guarantees. Please see the documentation: https://www.kubeflow.org/docs/pipelines/sdk/component-development/#writing-your-component-definition-file The components can be created manually (or, in case of python, using kfp.components.create_component_from_func or func_to_container_op) and then loaded using kfp.components.load_component_from_file, load_component_from_uri or load_component_from_text: https://kubeflow-pipelines.readthedocs.io/en/stable/source/kfp.components.html#kfp.components.load_component_from_file
#   category=FutureWarning,
# Please access the pipeline detail page at https://1b7bb986cc987470-dot-us-central1.pipelines.googleusercontent.com/#/pipelines/details/971b75c1-9e73-4ecd-be13-70b91137bc1a
# Pipeline "tfx_covertype_training" created successfully.

# %% [markdown]
# #### Pipeline runs can be created either through front-end UI or also thorugh tfx command

# %%
! tfx run create --pipeline_name={PIPELINE_NAME} --endpoint={ENDPOINT}
# Out:
# CLI
# Creating a run for pipeline: tfx_covertype_training
# Detected Kubeflow.
# Use --engine flag if you intend to use a different orchestrator.
# Run created for pipeline: tfx_covertype_training
# +========================+======================================+========+===========================+==============================================================================================================================+
# | pipeline_name          | run_id                               | status | created_at                | link                                                                                                                         |
# +========================+======================================+========+===========================+==============================================================================================================================+
# | tfx_covertype_training | 14058537-8361-4503-a5d7-4985dfabbbc7 | None   | 2021-12-18T18:02:05+00:00 | https://1b7bb986cc987470-dot-us-central1.pipelines.googleusercontent.com/#/runs/details/14058537-8361-4503-a5d7-4985dfabbbc7 |
# +========================+======================================+========+===========================+==============================================================================================================================+

# %%
! tfx run list --pipeline_name {PIPELINE_NAME} --endpoint {ENDPOINT}
# Out:
# CLI
# Listing all runs of pipeline: tfx_covertype_training
# Detected Kubeflow.
# Use --engine flag if you intend to use a different orchestrator.
# +========================+======================================+=========+===========================+==============================================================================================================================+
# | pipeline_name          | run_id                               | status  | created_at                | link                                                                                                                         |
# +========================+======================================+=========+===========================+==============================================================================================================================+
# | tfx_covertype_training | 1e40d136-8acf-4e80-8c46-3997ac1ee13f | Running | 2021-12-18T17:42:11+00:00 | https://1b7bb986cc987470-dot-us-central1.pipelines.googleusercontent.com/#/runs/details/1e40d136-8acf-4e80-8c46-3997ac1ee13f |
# +------------------------+--------------------------------------+---------+---------------------------+------------------------------------------------------------------------------------------------------------------------------+
# | tfx_covertype_training | 14058537-8361-4503-a5d7-4985dfabbbc7 | Failed  | 2021-12-18T18:02:05+00:00 | https://1b7bb986cc987470-dot-us-central1.pipelines.googleusercontent.com/#/runs/details/14058537-8361-4503-a5d7-4985dfabbbc7 |
# +========================+======================================+=========+===========================+==============================================================================================================================+

# %%
RUN_ID='1e40d136-8acf-4e80-8c46-3997ac1ee13f'

! tfx run status --pipeline_name {PIPELINE_NAME} --run_id {RUN_ID} --endpoint {ENDPOINT}
# Out:
# CLI
# Retrieving run status.
# Detected Kubeflow.
# Use --engine flag if you intend to use a different orchestrator.
# +========================+======================================+=========+===========================+==============================================================================================================================+
# | pipeline_name          | run_id                               | status  | created_at                | link                                                                                                                         |
# +========================+======================================+=========+===========================+==============================================================================================================================+
# | tfx_covertype_training | 1e40d136-8acf-4e80-8c46-3997ac1ee13f | Running | 2021-12-18T17:42:11+00:00 | https://1b7bb986cc987470-dot-us-central1.pipelines.googleusercontent.com/#/runs/details/1e40d136-8acf-4e80-8c46-3997ac1ee13f |
# +========================+======================================+=========+===========================+==============================================================================================================================+

# %% [markdown]
# #### Creating a pipeline run with tuning

# %%
os.environ['ENABLE_TUNING'] = str(True)

# %%
! tfx pipeline compile --engine kubeflow --pipeline_path runner.py
# Out:
# CLI
# Compiling pipeline
# WARNING:absl:`custom_executor_spec` is deprecated. Please customize component directly.
# WARNING:absl:`transformed_examples` is deprecated. Please use `examples` instead.
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying pipeline.py -> build/lib
# copying runner.py -> build/lib
# copying preprocessing.py -> build/lib
# copying features.py -> build/lib
# copying config.py -> build/lib
# copying model.py -> build/lib
# /opt/conda/lib/python3.7/site-packages/setuptools/command/install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   setuptools.SetuptoolsDeprecationWarning,
# installing to /tmp/tmpc7u67ar8
# running install
# running install_lib
# copying build/lib/preprocessing.py -> /tmp/tmpc7u67ar8
# copying build/lib/features.py -> /tmp/tmpc7u67ar8
# copying build/lib/pipeline.py -> /tmp/tmpc7u67ar8
# copying build/lib/config.py -> /tmp/tmpc7u67ar8
# copying build/lib/model.py -> /tmp/tmpc7u67ar8
# copying build/lib/runner.py -> /tmp/tmpc7u67ar8
# running install_egg_info
# running egg_info
# creating tfx_user_code_Transform.egg-info
# writing tfx_user_code_Transform.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Transform.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Transform.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# reading manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# Copying tfx_user_code_Transform.egg-info to /tmp/tmpc7u67ar8/tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6-py3.7.egg-info
# running install_scripts
# creating /tmp/tmpc7u67ar8/tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/WHEEL
# creating '/tmp/tmp2uwf36pc/tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6-py3-none-any.whl' and adding '/tmp/tmpc7u67ar8' to it
# adding 'config.py'
# adding 'features.py'
# adding 'model.py'
# adding 'pipeline.py'
# adding 'preprocessing.py'
# adding 'runner.py'
# adding 'tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/METADATA'
# adding 'tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/WHEEL'
# adding 'tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/top_level.txt'
# adding 'tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/RECORD'
# removing /tmp/tmpc7u67ar8
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying pipeline.py -> build/lib
# copying runner.py -> build/lib
# copying preprocessing.py -> build/lib
# copying features.py -> build/lib
# copying config.py -> build/lib
# copying model.py -> build/lib
# /opt/conda/lib/python3.7/site-packages/setuptools/command/install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   setuptools.SetuptoolsDeprecationWarning,
# installing to /tmp/tmpqa6rccx9
# running install
# running install_lib
# copying build/lib/preprocessing.py -> /tmp/tmpqa6rccx9
# copying build/lib/features.py -> /tmp/tmpqa6rccx9
# copying build/lib/pipeline.py -> /tmp/tmpqa6rccx9
# copying build/lib/config.py -> /tmp/tmpqa6rccx9
# copying build/lib/model.py -> /tmp/tmpqa6rccx9
# copying build/lib/runner.py -> /tmp/tmpqa6rccx9
# running install_egg_info
# running egg_info
# creating tfx_user_code_Tuner.egg-info
# writing tfx_user_code_Tuner.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Tuner.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Tuner.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Tuner.egg-info/SOURCES.txt'
# reading manifest file 'tfx_user_code_Tuner.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Tuner.egg-info/SOURCES.txt'
# Copying tfx_user_code_Tuner.egg-info to /tmp/tmpqa6rccx9/tfx_user_code_Tuner-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6-py3.7.egg-info
# running install_scripts
# creating /tmp/tmpqa6rccx9/tfx_user_code_Tuner-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/WHEEL
# creating '/tmp/tmpm74qjigx/tfx_user_code_Tuner-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6-py3-none-any.whl' and adding '/tmp/tmpqa6rccx9' to it
# adding 'config.py'
# adding 'features.py'
# adding 'model.py'
# adding 'pipeline.py'
# adding 'preprocessing.py'
# adding 'runner.py'
# adding 'tfx_user_code_Tuner-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/METADATA'
# adding 'tfx_user_code_Tuner-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/WHEEL'
# adding 'tfx_user_code_Tuner-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/top_level.txt'
# adding 'tfx_user_code_Tuner-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/RECORD'
# removing /tmp/tmpqa6rccx9
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying pipeline.py -> build/lib
# copying runner.py -> build/lib
# copying preprocessing.py -> build/lib
# copying features.py -> build/lib
# copying config.py -> build/lib
# copying model.py -> build/lib
# /opt/conda/lib/python3.7/site-packages/setuptools/command/install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   setuptools.SetuptoolsDeprecationWarning,
# installing to /tmp/tmpcfgfr29s
# running install
# running install_lib
# copying build/lib/preprocessing.py -> /tmp/tmpcfgfr29s
# copying build/lib/features.py -> /tmp/tmpcfgfr29s
# copying build/lib/pipeline.py -> /tmp/tmpcfgfr29s
# copying build/lib/config.py -> /tmp/tmpcfgfr29s
# copying build/lib/model.py -> /tmp/tmpcfgfr29s
# copying build/lib/runner.py -> /tmp/tmpcfgfr29s
# running install_egg_info
# running egg_info
# creating tfx_user_code_Trainer.egg-info
# writing tfx_user_code_Trainer.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Trainer.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Trainer.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# reading manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# Copying tfx_user_code_Trainer.egg-info to /tmp/tmpcfgfr29s/tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6-py3.7.egg-info
# running install_scripts
# creating /tmp/tmpcfgfr29s/tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/WHEEL
# creating '/tmp/tmpvim5xbbf/tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6-py3-none-any.whl' and adding '/tmp/tmpcfgfr29s' to it
# adding 'config.py'
# adding 'features.py'
# adding 'model.py'
# adding 'pipeline.py'
# adding 'preprocessing.py'
# adding 'runner.py'
# adding 'tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/METADATA'
# adding 'tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/WHEEL'
# adding 'tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/top_level.txt'
# adding 'tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/RECORD'
# removing /tmp/tmpcfgfr29s
# /opt/conda/lib/python3.7/site-packages/kfp/dsl/_container_op.py:1264: FutureWarning: Please create reusable components instead of constructing ContainerOp instances directly. Reusable components are shareable, portable and have compatibility and support guarantees. Please see the documentation: https://www.kubeflow.org/docs/pipelines/sdk/component-development/#writing-your-component-definition-file The components can be created manually (or, in case of python, using kfp.components.create_component_from_func or func_to_container_op) and then loaded using kfp.components.load_component_from_file, load_component_from_uri or load_component_from_text: https://kubeflow-pipelines.readthedocs.io/en/stable/source/kfp.components.html#kfp.components.load_component_from_file
#   category=FutureWarning,
# Pipeline compiled successfully.
# Pipeline package path: /home/jupyter/TFX-Pipelines-on-Google-Cloud/pipeline/tfx_covertype_training.tar.gz

# %%
! tfx pipeline update --pipeline_path runner.py --endpoint {ENDPOINT}
# Out:
# CLI
# Updating pipeline
# Detected Kubeflow.
# Use --engine flag if you intend to use a different orchestrator.
# WARNING:absl:`custom_executor_spec` is deprecated. Please customize component directly.
# WARNING:absl:`transformed_examples` is deprecated. Please use `examples` instead.
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying pipeline.py -> build/lib
# copying runner.py -> build/lib
# copying preprocessing.py -> build/lib
# copying features.py -> build/lib
# copying config.py -> build/lib
# copying model.py -> build/lib
# /opt/conda/lib/python3.7/site-packages/setuptools/command/install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   setuptools.SetuptoolsDeprecationWarning,
# installing to /tmp/tmpj8gpear9
# running install
# running install_lib
# copying build/lib/preprocessing.py -> /tmp/tmpj8gpear9
# copying build/lib/features.py -> /tmp/tmpj8gpear9
# copying build/lib/pipeline.py -> /tmp/tmpj8gpear9
# copying build/lib/config.py -> /tmp/tmpj8gpear9
# copying build/lib/model.py -> /tmp/tmpj8gpear9
# copying build/lib/runner.py -> /tmp/tmpj8gpear9
# running install_egg_info
# running egg_info
# creating tfx_user_code_Transform.egg-info
# writing tfx_user_code_Transform.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Transform.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Transform.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# reading manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# Copying tfx_user_code_Transform.egg-info to /tmp/tmpj8gpear9/tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6-py3.7.egg-info
# running install_scripts
# creating /tmp/tmpj8gpear9/tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/WHEEL
# creating '/tmp/tmphqnk28gx/tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6-py3-none-any.whl' and adding '/tmp/tmpj8gpear9' to it
# adding 'config.py'
# adding 'features.py'
# adding 'model.py'
# adding 'pipeline.py'
# adding 'preprocessing.py'
# adding 'runner.py'
# adding 'tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/METADATA'
# adding 'tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/WHEEL'
# adding 'tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/top_level.txt'
# adding 'tfx_user_code_Transform-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/RECORD'
# removing /tmp/tmpj8gpear9
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying pipeline.py -> build/lib
# copying runner.py -> build/lib
# copying preprocessing.py -> build/lib
# copying features.py -> build/lib
# copying config.py -> build/lib
# copying model.py -> build/lib
# /opt/conda/lib/python3.7/site-packages/setuptools/command/install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   setuptools.SetuptoolsDeprecationWarning,
# installing to /tmp/tmp7k_ccfdu
# running install
# running install_lib
# copying build/lib/preprocessing.py -> /tmp/tmp7k_ccfdu
# copying build/lib/features.py -> /tmp/tmp7k_ccfdu
# copying build/lib/pipeline.py -> /tmp/tmp7k_ccfdu
# copying build/lib/config.py -> /tmp/tmp7k_ccfdu
# copying build/lib/model.py -> /tmp/tmp7k_ccfdu
# copying build/lib/runner.py -> /tmp/tmp7k_ccfdu
# running install_egg_info
# running egg_info
# creating tfx_user_code_Tuner.egg-info
# writing tfx_user_code_Tuner.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Tuner.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Tuner.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Tuner.egg-info/SOURCES.txt'
# reading manifest file 'tfx_user_code_Tuner.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Tuner.egg-info/SOURCES.txt'
# Copying tfx_user_code_Tuner.egg-info to /tmp/tmp7k_ccfdu/tfx_user_code_Tuner-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6-py3.7.egg-info
# running install_scripts
# creating /tmp/tmp7k_ccfdu/tfx_user_code_Tuner-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/WHEEL
# creating '/tmp/tmpqpyh6499/tfx_user_code_Tuner-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6-py3-none-any.whl' and adding '/tmp/tmp7k_ccfdu' to it
# adding 'config.py'
# adding 'features.py'
# adding 'model.py'
# adding 'pipeline.py'
# adding 'preprocessing.py'
# adding 'runner.py'
# adding 'tfx_user_code_Tuner-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/METADATA'
# adding 'tfx_user_code_Tuner-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/WHEEL'
# adding 'tfx_user_code_Tuner-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/top_level.txt'
# adding 'tfx_user_code_Tuner-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/RECORD'
# removing /tmp/tmp7k_ccfdu
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying pipeline.py -> build/lib
# copying runner.py -> build/lib
# copying preprocessing.py -> build/lib
# copying features.py -> build/lib
# copying config.py -> build/lib
# copying model.py -> build/lib
# /opt/conda/lib/python3.7/site-packages/setuptools/command/install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   setuptools.SetuptoolsDeprecationWarning,
# installing to /tmp/tmp1ctcv0kz
# running install
# running install_lib
# copying build/lib/preprocessing.py -> /tmp/tmp1ctcv0kz
# copying build/lib/features.py -> /tmp/tmp1ctcv0kz
# copying build/lib/pipeline.py -> /tmp/tmp1ctcv0kz
# copying build/lib/config.py -> /tmp/tmp1ctcv0kz
# copying build/lib/model.py -> /tmp/tmp1ctcv0kz
# copying build/lib/runner.py -> /tmp/tmp1ctcv0kz
# running install_egg_info
# running egg_info
# creating tfx_user_code_Trainer.egg-info
# writing tfx_user_code_Trainer.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Trainer.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Trainer.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# reading manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# Copying tfx_user_code_Trainer.egg-info to /tmp/tmp1ctcv0kz/tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6-py3.7.egg-info
# running install_scripts
# creating /tmp/tmp1ctcv0kz/tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/WHEEL
# creating '/tmp/tmpgzvmhq2w/tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6-py3-none-any.whl' and adding '/tmp/tmp1ctcv0kz' to it
# adding 'config.py'
# adding 'features.py'
# adding 'model.py'
# adding 'pipeline.py'
# adding 'preprocessing.py'
# adding 'runner.py'
# adding 'tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/METADATA'
# adding 'tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/WHEEL'
# adding 'tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/top_level.txt'
# adding 'tfx_user_code_Trainer-0.0+bf71de72f116bc10246a4e3d24a8cd30db495fe81f925b530adf12cc0339aeb6.dist-info/RECORD'
# removing /tmp/tmp1ctcv0kz
# /opt/conda/lib/python3.7/site-packages/kfp/dsl/_container_op.py:1264: FutureWarning: Please create reusable components instead of constructing ContainerOp instances directly. Reusable components are shareable, portable and have compatibility and support guarantees. Please see the documentation: https://www.kubeflow.org/docs/pipelines/sdk/component-development/#writing-your-component-definition-file The components can be created manually (or, in case of python, using kfp.components.create_component_from_func or func_to_container_op) and then loaded using kfp.components.load_component_from_file, load_component_from_uri or load_component_from_text: https://kubeflow-pipelines.readthedocs.io/en/stable/source/kfp.components.html#kfp.components.load_component_from_file
#   category=FutureWarning,
# Please access the pipeline detail page at https://1b7bb986cc987470-dot-us-central1.pipelines.googleusercontent.com/#/pipelines/details/971b75c1-9e73-4ecd-be13-70b91137bc1a
# Pipeline "tfx_covertype_training" updated successfully.

# %%
! tfx run create --pipeline_name={PIPELINE_NAME} --endpoint={ENDPOINT}
# Out:
# CLI
# Creating a run for pipeline: tfx_covertype_training
# Detected Kubeflow.
# Use --engine flag if you intend to use a different orchestrator.
# Run created for pipeline: tfx_covertype_training
# +========================+======================================+========+===========================+==============================================================================================================================+
# | pipeline_name          | run_id                               | status | created_at                | link                                                                                                                         |
# +========================+======================================+========+===========================+==============================================================================================================================+
# | tfx_covertype_training | a6ffda91-4c63-4ea8-a1f4-34845d92c62d | None   | 2021-12-18T18:18:25+00:00 | https://1b7bb986cc987470-dot-us-central1.pipelines.googleusercontent.com/#/runs/details/a6ffda91-4c63-4ea8-a1f4-34845d92c62d |
# +========================+======================================+========+===========================+==============================================================================================================================+
